# %% [markdown]
# <a href="https://colab.research.google.com/github/Chygos/Zindi/blob/main/Runmila%20Tuberculosis%20clasification/Runmila_TB_Classification4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, files

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = "drive/My Drive/Zindi/TB XRay Challenge/"

# %%
# !pip install imutils -q
import os,gc, warnings
warnings.filterwarnings('ignore')

# %%
#os.listdir(path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix, roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split, StratifiedKFold
import seaborn as sns
import cv2, imutils
from functools import partial

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.keras import layers, optimizers, Sequential,Model
import tensorflow.keras as tf_keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Flatten, BatchNormalization, Conv2D
from tensorflow.keras.applications import VGG16, InceptionV3
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess_input
from tensorflow.keras.applications.xception import preprocess_input as inception_preprocess_input

# %%
#for reproducibility
SEED = 123
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
train = pd.read_csv(path+'Train.csv')
test = pd.read_csv(path+'Test.csv')
subfile = pd.read_csv(path+'SampleSubmission.csv')
train_path = path+'train_small/'
test_path = path+'test_small/'

# %%
train.shape,test.shape
# Out:
# ((718, 3), (82, 2))

# %%
train.head(4)
# Out:
#              filename        ID  LABEL
# 0  train/VTYNBFTO.png  VTYNBFTO      1
# 1  train/GVVXXDOZ.png  GVVXXDOZ      0
# 2  train/PMRSQLXN.png  PMRSQLXN      0
# 3  train/JXISWDUU.png  JXISWDUU      1

# %%
test.head(3)
# Out:
#             filename        ID
# 0  test/GTWSHFYQ.png  GTWSHFYQ
# 1  test/QTFSSMGD.png  QTFSSMGD
# 2  test/TBLBHSYT.png  TBLBHSYT

# %%
subfile.head(2)
# Out:
#          ID  LABEL
# 0  GTWSHFYQ      0
# 1  QTFSSMGD      0

# %%
train_ids = train.ID.values
test_ids = test.ID.values
train_labels = train.LABEL

# %%
train_images = pd.DataFrame({'filepath' : train_path+train_ids+'.png', 'ID' : train_ids, 'LABEL' : train_labels})
test_images = pd.DataFrame({'filepath' : test_path+test_ids+'.png', 'ID' : test_ids})

# %%
ax = sns.countplot(train_images.LABEL)
plt.xticks(range(2), ['Negative', 'Positive'])
for i in ax.patches:
  plt.text(i.get_x()+0.3, i.get_height()+0.2, str(np.round(i.get_height()/len(train),2)*100)+'%',
           fontsize=12, fontweight=60)
plt.title('Target Distribution');

# %%
train_images.head(2)
# Out:
#                                             filepath        ID  LABEL
# 0  drive/My Drive/Zindi/TB XRay Challenge/train_s...  VTYNBFTO      1
# 1  drive/My Drive/Zindi/TB XRay Challenge/train_s...  GVVXXDOZ      0

# %%
plt.figure(figsize=(12,10))
for i in range(9):
  img_data = train_images.sample(1)
  img = cv2.imread(img_data.iloc[0].filepath)
  plt.subplot(3,3, i+1)
  plt.imshow(img)
  label_map = {0:'Negative', 1:'Positive'}
  plt.title(label_map.get(img_data.LABEL.iloc[0], None))
plt.suptitle('Train Images');

# %%
f = cv2.imread(train_images.sample(1).iloc[0].filepath)
f.shape
#The image is of shape 797 x 800 pixels
# Out:
# (800, 775, 3)

# %% [markdown]
# Image Processing
# In order to crop the part that contains only the chest region from the image, I used a cropping technique to find the extreme top, bottom, left and right points of the brain. This code was gotten from <a href="https://github.com/Chygos/Brain-Tumor-Detection/blob/master/Brain%20Tumor%20Detection.ipynb"> this link.</a>

# %%
def crop_chest_contour(image, plot=False):
  """
  This crops the image to get a clear view of the affected chest region
  parameters
  ----------
  image: Image
  plot: For plotting original and cropped images
  """  
  # Convert the image to grayscale, and blur it slightly
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  gray = cv2.GaussianBlur(gray, (5, 5), 0)

  # Threshold the image, then perform a series of erosions +
  # dilations to remove any small regions of noise
  thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
  thresh = cv2.erode(thresh, None, iterations=2)
  thresh = cv2.dilate(thresh, None, iterations=2)

  # Find contours in thresholded image, then grab the largest one
  cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  c = max(cnts, key=cv2.contourArea)
  

  # Find the extreme points
  extLeft = tuple(c[c[:, :, 0].argmin()][0])
  extRight = tuple(c[c[:, :, 0].argmax()][0])
  extTop = tuple(c[c[:, :, 1].argmin()][0])
  extBot = tuple(c[c[:, :, 1].argmax()][0])
  
  # crop new image out of the original image using the four extreme points (left, right, top, bottom)
  new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

  if plot:
      plt.figure()

      plt.subplot(1, 2, 1)
      plt.imshow(image)
      
      plt.tick_params(axis='both', which='both', 
                      top=False, bottom=False, left=False, right=False,
                      labelbottom=False, labeltop=False, labelleft=False, labelright=False)
      
      plt.title('Original Image')
          
      plt.subplot(1, 2, 2)
      plt.imshow(new_image)

      plt.tick_params(axis='both', which='both', 
                      top=False, bottom=False, left=False, right=False,
                      labelbottom=False, labeltop=False, labelleft=False, labelright=False)

      plt.title('Cropped Image')
      
      plt.show()
  
  return new_image

# %%
img_crop = crop_chest_contour(f,plot=True)

# %%
def plot_sample_images(X, y, n=10):
  """
  Plots n sample images for both values of y (labels).
  Arguments:
  X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
  y: A numpy array with shape = (#_examples, 1)
  """  
  for label in [0,1]:

    # grab the first n images with the corresponding y values equal to label
    images = X[X.LABEL == label].filepath
    n_images = images[:n]
      
    columns_n = 5
    rows_n = int(n/ columns_n)
    plt.figure(figsize=(20, 10))
    # i = 1 # current plot
    for i, image in enumerate(n_images, start=1):
      image = cv2.imread(image)
      plt.subplot(rows_n, columns_n, i)
      plt.imshow(cv2.resize(image, dsize=(224,224), fx= 0.7, fy= 0.7, interpolation=cv2.INTER_CUBIC))
      # remove ticks
      plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,
                      labelbottom=False, labeltop=False, labelleft=False, labelright=False)
      # i += 1
    label_to_str = lambda label: "Yes" if label == 1 else "No"
    plt.suptitle(f"TUBERCULOUSIS: {label_to_str(label)}");
    # plt.show()

# %%
plot_sample_images(train_images,  train_images.LABEL,n=10)

# %%
#splitting data into train and validatio sets
train_data, valid_data= train_test_split(train_images, random_state=SEED, test_size=0.2, stratify=train_images.LABEL)

# %%
train_data.shape, valid_data.shape
# Out:
# ((574, 3), (144, 3))

# %%
print(train_data.LABEL.value_counts())
print(valid_data.LABEL.value_counts())
# Out:
# 0    292
# 1    282
# Name: LABEL, dtype: int64
# 0    73
# 1    71
# Name: LABEL, dtype: int64

# %%
train_data.LABEL = train_data.LABEL.map({0:'Negative', 1:'Positive'}) #converting label to string for image data generator requirement
valid_data.LABEL = valid_data.LABEL.map({0:'Negative', 1:'Positive'})

# %% [markdown]
# **VGG**

# %%
#Data generators and data augmentation of train set
train_datagen = ImageDataGenerator(preprocessing_function=vgg_preprocess_input, 
                                   horizontal_flip=True, vertical_flip=True,zoom_range=0.1, 
                                   rotation_range=10, width_shift_range=0.2, height_shift_range=0.1, 
                                   channel_shift_range=1., shear_range=0.1, fill_mode='nearest', 
                                   brightness_range=(0.3, 1.0))

valid_datagen = ImageDataGenerator(preprocessing_function=vgg_preprocess_input) #dont perform data augmentation on both validation and test sets

# %%
image_size= (224,224)
batch_size = 32
train_steps = len(train_data) // batch_size
valid_steps = len(valid_data) // batch_size

classes = train_data.LABEL.unique().tolist()

# %%
train_gen= train_datagen.flow_from_dataframe(train_data, x_col = 'filepath', y_col='LABEL', target_size=image_size, classes=classes,
                                             class_mode='categorical', seed=SEED, batch_size=batch_size, shuffle=True)

val_gen = valid_datagen.flow_from_dataframe(valid_data, x_col='filepath', y_col='LABEL', target_size=image_size, class_mode='categorical',
                                            classes=classes, shuffle=False, batch_size=batch_size, seed=SEED)#dont shuffle val or test data

test_gen = valid_datagen.flow_from_dataframe(test_images, class_mode=None, x_col = 'filepath', target_size=image_size, shuffle=False, 
                                             batch_size=batch_size)
# Out:
# Found 574 validated image filenames belonging to 2 classes.
# Found 144 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames.

# %% [markdown]
# **Model Building**

# %% [markdown]
# **`With Pretrained Models`**

# %%
input_shape= (224, 224, 3) #height, width, channels

# %%
def BaseModel(base_model=VGG16):
  """Functional API of Keras
  """
  base_model= base_model(include_top=False, weights='imagenet', input_shape=input_shape)
  x = GlobalAveragePooling2D(name='avg_pool')(base_model.output)
  # x = BatchNormalization()(x)
  x = Dropout(0.2, name='top_dropout')(x)
  output = Dense(2, name='output_layer')(x)
  output = layers.Activation('softmax')(output)
  model = Model(base_model.input, output)
  base_model.trainable = False #freezing weights of base model to only train on the last layers added
  return model

# %%
model = BaseModel()

# %%
#checking if base model weights are frozen
model.layers[0].trainable
# Out:
# False

# %%
model.summary()
# Out:
# Model: "functional_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 512)               0
# _________________________________________________________________
# top_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 2)                 1026
# _________________________________________________________________
# activation_10 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 14,715,714
# Trainable params: 1,026
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=1e-3), metrics=['AUC'])

# %%
es = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)
checkpoint_path = os.path.join(path, 'vgg_pretrained_model3.h5')
modelcheck = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', 
                             mode='auto', save_best_only=True, verbose=1)

# %%
history = model.fit(train_gen, epochs=30, steps_per_epoch=train_steps, shuffle=True, validation_steps=valid_steps,
                    validation_data=(val_gen), callbacks=[es, modelcheck], verbose=2);
# Out:
# Epoch 1/30
#
# Epoch 00001: val_loss improved from inf to 1.21435, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 15s - loss: 1.2348 - auc: 0.6547 - val_loss: 1.2144 - val_auc: 0.6660
# Epoch 2/30
#
# Epoch 00002: val_loss improved from 1.21435 to 0.99039, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 15s - loss: 1.1511 - auc: 0.6923 - val_loss: 0.9904 - val_auc: 0.7095
# Epoch 3/30
#
# Epoch 00003: val_loss improved from 0.99039 to 0.96008, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.9783 - auc: 0.7126 - val_loss: 0.9601 - val_auc: 0.7260
# Epoch 4/30
#
# Epoch 00004: val_loss improved from 0.96008 to 0.94312, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.8472 - auc: 0.7758 - val_loss: 0.9431 - val_auc: 0.7429
# Epoch 5/30
#
# Epoch 00005: val_loss improved from 0.94312 to 0.90631, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.8834 - auc: 0.7575 - val_loss: 0.9063 - val_auc: 0.7614
# Epoch 6/30
#
# Epoch 00006: val_loss improved from 0.90631 to 0.88500, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 15s - loss: 0.8359 - auc: 0.7742 - val_loss: 0.8850 - val_auc: 0.7585
# Epoch 7/30
#
# Epoch 00007: val_loss did not improve from 0.88500
# 17/17 - 14s - loss: 0.7800 - auc: 0.7825 - val_loss: 0.9405 - val_auc: 0.7595
# Epoch 8/30
#
# Epoch 00008: val_loss improved from 0.88500 to 0.83043, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.8059 - auc: 0.7744 - val_loss: 0.8304 - val_auc: 0.7791
# Epoch 9/30
#
# Epoch 00009: val_loss improved from 0.83043 to 0.79229, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.7019 - auc: 0.8042 - val_loss: 0.7923 - val_auc: 0.7958
# Epoch 10/30
#
# Epoch 00010: val_loss improved from 0.79229 to 0.70701, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.7825 - auc: 0.7756 - val_loss: 0.7070 - val_auc: 0.8179
# Epoch 11/30
#
# Epoch 00011: val_loss did not improve from 0.70701
# 17/17 - 13s - loss: 0.6467 - auc: 0.8200 - val_loss: 0.7205 - val_auc: 0.8169
# Epoch 12/30
#
# Epoch 00012: val_loss improved from 0.70701 to 0.68597, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.7312 - auc: 0.7951 - val_loss: 0.6860 - val_auc: 0.8273
# Epoch 13/30
#
# Epoch 00013: val_loss did not improve from 0.68597
# 17/17 - 13s - loss: 0.6836 - auc: 0.8199 - val_loss: 0.7303 - val_auc: 0.8171
# Epoch 14/30
#
# Epoch 00014: val_loss did not improve from 0.68597
# 17/17 - 13s - loss: 0.7021 - auc: 0.8086 - val_loss: 0.7091 - val_auc: 0.8192
# Epoch 15/30
#
# Epoch 00015: val_loss did not improve from 0.68597
# 17/17 - 13s - loss: 0.6420 - auc: 0.8186 - val_loss: 0.7036 - val_auc: 0.8203
# Epoch 16/30
#
# Epoch 00016: val_loss improved from 0.68597 to 0.61261, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.6343 - auc: 0.8249 - val_loss: 0.6126 - val_auc: 0.8364
# Epoch 17/30
#
# Epoch 00017: val_loss improved from 0.61261 to 0.57969, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.6688 - auc: 0.8039 - val_loss: 0.5797 - val_auc: 0.8425
# Epoch 18/30
#
# Epoch 00018: val_loss did not improve from 0.57969
# 17/17 - 13s - loss: 0.6089 - auc: 0.8323 - val_loss: 0.5899 - val_auc: 0.8441
# Epoch 19/30
#
# Epoch 00019: val_loss improved from 0.57969 to 0.56051, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 13s - loss: 0.5956 - auc: 0.8268 - val_loss: 0.5605 - val_auc: 0.8492
# Epoch 20/30
#
# Epoch 00020: val_loss improved from 0.56051 to 0.54484, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.5375 - auc: 0.8510 - val_loss: 0.5448 - val_auc: 0.8615
# Epoch 21/30
#
# Epoch 00021: val_loss did not improve from 0.54484
# 17/17 - 13s - loss: 0.5336 - auc: 0.8532 - val_loss: 0.5525 - val_auc: 0.8559
# Epoch 22/30
#
# Epoch 00022: val_loss did not improve from 0.54484
# 17/17 - 13s - loss: 0.5352 - auc: 0.8494 - val_loss: 0.5452 - val_auc: 0.8581
# Epoch 23/30
#
# Epoch 00023: val_loss did not improve from 0.54484
# 17/17 - 13s - loss: 0.5562 - auc: 0.8372 - val_loss: 0.8124 - val_auc: 0.7990
# Epoch 24/30
#
# Epoch 00024: val_loss did not improve from 0.54484
# 17/17 - 13s - loss: 0.5347 - auc: 0.8507 - val_loss: 0.6313 - val_auc: 0.8374
# Epoch 25/30
#
# Epoch 00025: val_loss did not improve from 0.54484
# 17/17 - 13s - loss: 0.5074 - auc: 0.8627 - val_loss: 0.7081 - val_auc: 0.8212
# Epoch 26/30
#
# Epoch 00026: val_loss improved from 0.54484 to 0.52791, saving model to drive/My Drive/Zindi/TB XRay Challenge/vgg_pretrained_model3.h5
# 17/17 - 14s - loss: 0.4741 - auc: 0.8728 - val_loss: 0.5279 - val_auc: 0.8658
# Epoch 27/30
#
# Epoch 00027: val_loss did not improve from 0.52791
# 17/17 - 13s - loss: 0.5597 - auc: 0.8425 - val_loss: 0.5541 - val_auc: 0.8535
# Epoch 28/30
#
# Epoch 00028: val_loss did not improve from 0.52791
# 17/17 - 13s - loss: 0.5059 - auc: 0.8606 - val_loss: 0.5498 - val_auc: 0.8509
# Epoch 29/30
#
# Epoch 00029: val_loss did not improve from 0.52791
# 17/17 - 13s - loss: 0.5412 - auc: 0.8486 - val_loss: 0.7920 - val_auc: 0.8066
# Epoch 30/30
#
# Epoch 00030: val_loss did not improve from 0.52791
# 17/17 - 13s - loss: 0.5183 - auc: 0.8540 - val_loss: 0.7464 - val_auc: 0.8064

# %%
tr_auc = history.history['auc']
val_auc = history.history['val_auc']
tr_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(range(1, len(tr_auc)+1), tr_auc, 'b-*', label='train_auc')
plt.plot(range(1, len(tr_auc)+1), val_auc, 'r-*', label='val_auc')
plt.title('AUC')
plt.legend()

plt.subplot(122)
plt.plot(range(1, len(tr_auc)+1), tr_loss, 'b-*', label='train_loss')
plt.plot(range(1, len(tr_auc)+1), val_loss, 'r-*', label='val_loss')
plt.title('Loss')
plt.legend();

# %% [markdown]
# **Fine Tuning Model**

# %%
#vgg_model = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)

# %%
def fineTuneModel(base_model=VGG16):
  """
  Fine tunes the model by unfreezing some of the layers in the pretrained model
  """
  base_model= base_model(include_top=False, weights='imagenet', input_shape=input_shape)
  base_model.trainable = False #freezing weights of base model
  
  #unfreezing layers 4 and 5
  for layer in base_model.layers:
    if 'block4' in layer.name or 'block5' in layer.name:
      layer.trainable = True

  x = GlobalAveragePooling2D(name='avg_pool_ftune')(base_model.output)
  # x = BatchNormalization()(x)
  x = Dropout(0.2, name='top_dropout')(x)
  output = Dense(2, name='output_layer')(x)
  output = layers.Activation('softmax')(output)
  model = Model(base_model.input, output,name='Finetune')
  return model

# %%
model = fineTuneModel()

# %%
model.summary()
# Out:
# Model: "Finetune"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# avg_pool_ftune (GlobalAverag (None, 512)               0
# _________________________________________________________________
# top_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 2)                 1026
# _________________________________________________________________
# activation_16 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 14,715,714
# Trainable params: 12,980,226
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=1e-5), metrics=['AUC']) #reducing the learning rate

# %%
es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
checkpoint_path = os.path.join(path, 'fineTuned_vgg_pretrained_model3.h5')
modelcheck = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', mode='auto', save_best_only=True, verbose=1)

# %%
history = model.fit(train_gen, epochs=50, steps_per_epoch=train_steps, shuffle=True, validation_steps=valid_steps,
                    validation_data=(val_gen), callbacks=[es, modelcheck], verbose=1);
# Out:
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 1.2435 - auc: 0.6294
# Epoch 00001: val_loss improved from inf to 1.13046, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 16s 929ms/step - loss: 1.2435 - auc: 0.6294 - val_loss: 1.1305 - val_auc: 0.6511
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6588 - auc: 0.7495
# Epoch 00002: val_loss improved from 1.13046 to 0.91900, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 900ms/step - loss: 0.6588 - auc: 0.7495 - val_loss: 0.9190 - val_auc: 0.7064
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6088 - auc: 0.7732
# Epoch 00003: val_loss improved from 0.91900 to 0.67684, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 894ms/step - loss: 0.6088 - auc: 0.7732 - val_loss: 0.6768 - val_auc: 0.7754
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5456 - auc: 0.8049
# Epoch 00004: val_loss improved from 0.67684 to 0.62804, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 16s 925ms/step - loss: 0.5456 - auc: 0.8049 - val_loss: 0.6280 - val_auc: 0.7994
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4917 - auc: 0.8442
# Epoch 00005: val_loss did not improve from 0.62804
# 17/17 [==============================] - 14s 825ms/step - loss: 0.4917 - auc: 0.8442 - val_loss: 0.6421 - val_auc: 0.8116
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4820 - auc: 0.8539
# Epoch 00006: val_loss improved from 0.62804 to 0.61572, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 858ms/step - loss: 0.4820 - auc: 0.8539 - val_loss: 0.6157 - val_auc: 0.8237
# Epoch 7/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4146 - auc: 0.8944
# Epoch 00007: val_loss did not improve from 0.61572
# 17/17 [==============================] - 14s 826ms/step - loss: 0.4146 - auc: 0.8944 - val_loss: 0.8449 - val_auc: 0.7847
# Epoch 8/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4429 - auc: 0.8779
# Epoch 00008: val_loss improved from 0.61572 to 0.53869, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 863ms/step - loss: 0.4429 - auc: 0.8779 - val_loss: 0.5387 - val_auc: 0.8417
# Epoch 9/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3937 - auc: 0.9035
# Epoch 00009: val_loss improved from 0.53869 to 0.49448, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 887ms/step - loss: 0.3937 - auc: 0.9035 - val_loss: 0.4945 - val_auc: 0.8695
# Epoch 10/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4026 - auc: 0.9012
# Epoch 00010: val_loss did not improve from 0.49448
# 17/17 [==============================] - 14s 825ms/step - loss: 0.4026 - auc: 0.9012 - val_loss: 0.5065 - val_auc: 0.8741
# Epoch 11/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4184 - auc: 0.8919
# Epoch 00011: val_loss improved from 0.49448 to 0.46472, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 870ms/step - loss: 0.4184 - auc: 0.8919 - val_loss: 0.4647 - val_auc: 0.8755
# Epoch 12/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4024 - auc: 0.9012
# Epoch 00012: val_loss improved from 0.46472 to 0.45689, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 874ms/step - loss: 0.4024 - auc: 0.9012 - val_loss: 0.4569 - val_auc: 0.8815
# Epoch 13/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3761 - auc: 0.9133
# Epoch 00013: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 830ms/step - loss: 0.3761 - auc: 0.9133 - val_loss: 0.8598 - val_auc: 0.7877
# Epoch 14/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3666 - auc: 0.9236
# Epoch 00014: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 809ms/step - loss: 0.3666 - auc: 0.9236 - val_loss: 0.9012 - val_auc: 0.7572
# Epoch 15/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3410 - auc: 0.9272
# Epoch 00015: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 814ms/step - loss: 0.3410 - auc: 0.9272 - val_loss: 0.5769 - val_auc: 0.8577
# Epoch 16/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3302 - auc: 0.9341
# Epoch 00016: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 814ms/step - loss: 0.3302 - auc: 0.9341 - val_loss: 0.6303 - val_auc: 0.8444
# Epoch 17/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3112 - auc: 0.9401
# Epoch 00017: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 818ms/step - loss: 0.3112 - auc: 0.9401 - val_loss: 0.4697 - val_auc: 0.9010
# Epoch 18/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3324 - auc: 0.9331
# Epoch 00018: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 815ms/step - loss: 0.3324 - auc: 0.9331 - val_loss: 0.5651 - val_auc: 0.8785
# Epoch 19/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3558 - auc: 0.9231
# Epoch 00019: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 818ms/step - loss: 0.3558 - auc: 0.9231 - val_loss: 0.5362 - val_auc: 0.8620
# Epoch 20/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3081 - auc: 0.9423
# Epoch 00020: val_loss did not improve from 0.45689
# 17/17 [==============================] - 14s 820ms/step - loss: 0.3081 - auc: 0.9423 - val_loss: 0.4710 - val_auc: 0.8976
# Epoch 21/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3027 - auc: 0.9432
# Epoch 00021: val_loss improved from 0.45689 to 0.38568, saving model to drive/My Drive/Zindi/TB XRay Challenge/fineTuned_vgg_pretrained_model3.h5
# 17/17 [==============================] - 15s 904ms/step - loss: 0.3027 - auc: 0.9432 - val_loss: 0.3857 - val_auc: 0.9166
# Epoch 22/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2703 - auc: 0.9555
# Epoch 00022: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 819ms/step - loss: 0.2703 - auc: 0.9555 - val_loss: 0.4369 - val_auc: 0.9102
# Epoch 23/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3075 - auc: 0.9414
# Epoch 00023: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 817ms/step - loss: 0.3075 - auc: 0.9414 - val_loss: 0.4030 - val_auc: 0.9222
# Epoch 24/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2779 - auc: 0.9530
# Epoch 00024: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 813ms/step - loss: 0.2779 - auc: 0.9530 - val_loss: 0.7337 - val_auc: 0.8145
# Epoch 25/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3126 - auc: 0.9400
# Epoch 00025: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 805ms/step - loss: 0.3126 - auc: 0.9400 - val_loss: 0.6742 - val_auc: 0.8330
# Epoch 26/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2569 - auc: 0.9601
# Epoch 00026: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 811ms/step - loss: 0.2569 - auc: 0.9601 - val_loss: 0.4178 - val_auc: 0.9172
# Epoch 27/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2782 - auc: 0.9517
# Epoch 00027: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 815ms/step - loss: 0.2782 - auc: 0.9517 - val_loss: 0.3953 - val_auc: 0.9227
# Epoch 28/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2873 - auc: 0.9495
# Epoch 00028: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 822ms/step - loss: 0.2873 - auc: 0.9495 - val_loss: 0.5752 - val_auc: 0.8727
# Epoch 29/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2683 - auc: 0.9568
# Epoch 00029: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 823ms/step - loss: 0.2683 - auc: 0.9568 - val_loss: 0.5190 - val_auc: 0.8832
# Epoch 30/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2442 - auc: 0.9634
# Epoch 00030: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 835ms/step - loss: 0.2442 - auc: 0.9634 - val_loss: 0.7283 - val_auc: 0.8424
# Epoch 31/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2565 - auc: 0.9599Restoring model weights from the end of the best epoch.
#
# Epoch 00031: val_loss did not improve from 0.38568
# 17/17 [==============================] - 14s 811ms/step - loss: 0.2565 - auc: 0.9599 - val_loss: 0.4961 - val_auc: 0.8919
# Epoch 00031: early stopping

# %%
tr_auc = history.history['auc']
val_auc = history.history['val_auc']
tr_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(range(1, len(tr_auc)+1), tr_auc, 'b-*', label='train_auc')
plt.plot(range(1, len(tr_auc)+1), val_auc, 'r-*', label='val_auc')
plt.title('AUC')
plt.legend()

plt.subplot(122)
plt.plot(range(1, len(tr_auc)+1), tr_loss, 'b-*', label='train_loss')
plt.plot(range(1, len(tr_auc)+1), val_loss, 'r-*', label='val_loss')
plt.title('Loss')
plt.legend();

# %% [markdown]
# <b>Predictions</b>

# %%
y_preds = model.predict(val_gen)[:,1]

# %%
auc_score = roc_auc_score(val_gen.classes, y_preds)
fpr, tpr, thresholds = roc_curve(val_gen.classes, y_preds)

# %%
auc(fpr, tpr)
# Out:
# 0.9125988809569747

# %%
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc_score))
plt.plot([0,1], [0,1], 'k--')
plt.title('ROC CURVE')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend();

# %% [markdown]
# **Submission**

# %%
test_preds = model.predict(test_gen)[:, 1]

# %%
submission = pd.DataFrame({'ID': test_ids, 'LABEL':test_preds})

# %%
submission.head()
# Out:
#          ID     LABEL
# 0  GTWSHFYQ  0.133939
# 1  QTFSSMGD  0.007999
# 2  TBLBHSYT  0.970735
# 3  ZKETEOFG  0.675017
# 4  GKTPBGZP  0.594142

# %%
submission.to_csv(os.path.join(path, 'finetuned_vgg_pretrained_model3.csv'), index=False)

# %%
files.download(path+'finetuned_vgg_pretrained_model3.csv')

# %% [markdown]
# **LB Score = ~0.9457**<br>
# **Final LB = ~0.9211**

# %%
gc.collect()
# Out:
# 2627
